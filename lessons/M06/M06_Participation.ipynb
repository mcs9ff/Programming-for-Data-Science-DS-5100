# %%
# Module 6 Participation

# %%
# Matt Scheffel
# mcs9ff

# %%
# Review

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series, DataFrame

iris = sns.load_dataset("iris")

iris.index.name = 'iris_id'

iris
# Out:
#          sepal_length  sepal_width  petal_length  petal_width    species
# iris_id
# 0                 5.1          3.5           1.4          0.2     setosa
# 1                 4.9          3.0           1.4          0.2     setosa
# 2                 4.7          3.2           1.3          0.2     setosa
# 3                 4.6          3.1           1.5          0.2     setosa
# 4                 5.0          3.6           1.4          0.2     setosa
# ...               ...          ...           ...          ...        ...
# 145               6.7          3.0           5.2          2.3  virginica
# 146               6.3          2.5           5.0          1.9  virginica
# 147               6.5          3.0           5.2          2.0  virginica
# 148               6.2          3.4           5.4          2.3  virginica
# 149               5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris = iris.reset_index().set_index(['species', 'iris_id'])

# %%
iris
# Out:
#          sepal_length  sepal_width  petal_length  petal_width    species
# iris_id
# 0                 5.1          3.5           1.4          0.2     setosa
# 1                 4.9          3.0           1.4          0.2     setosa
# 2                 4.7          3.2           1.3          0.2     setosa
# 3                 4.6          3.1           1.5          0.2     setosa
# 4                 5.0          3.6           1.4          0.2     setosa
# ...               ...          ...           ...          ...        ...
# 145               6.7          3.0           5.2          2.3  virginica
# 146               6.3          2.5           5.0          1.9  virginica
# 147               6.5          3.0           5.2          2.0  virginica
# 148               6.2          3.4           5.4          2.3  virginica
# 149               5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.groupby('species')\
    .agg({'mean', 'min', 'max'})\
    .T\
    .style.background_gradient(cmap="GnBu", axis=1)
# Out:
# <style  type="text/css" >
# #T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row0_col0,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row1_col0,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row2_col0,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row3_col1,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row4_col1,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row5_col1,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row6_col0,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row7_col0,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row8_col0,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row9_col0,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row10_col0,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row11_col0{
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row0_col1,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row8_col1{
#             background-color:  #61bdcd;
#             color:  #000000;
#         }#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row0_col2,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row1_col2,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row2_col1,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row2_col2,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row3_col0,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row4_col0,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row5_col0,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row6_col2,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row7_col2,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row8_col2,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row9_col2,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row10_col2,#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row11_col2{
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row1_col1{
#             background-color:  #5bbacf;
#             color:  #000000;
#         }#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row3_col2{
#             background-color:  #9fdab8;
#             color:  #000000;
#         }#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row4_col2{
#             background-color:  #bbe4bd;
#             color:  #000000;
#         }#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row5_col2{
#             background-color:  #42a6cc;
#             color:  #000000;
#         }#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row6_col1{
#             background-color:  #4aafd1;
#             color:  #000000;
#         }#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row7_col1{
#             background-color:  #3da0c9;
#             color:  #000000;
#         }#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row9_col1{
#             background-color:  #4cb1d2;
#             color:  #000000;
#         }#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row10_col1{
#             background-color:  #54b6d1;
#             color:  #000000;
#         }#T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row11_col1{
#             background-color:  #3b9dc7;
#             color:  #000000;
#         }</style><table id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >species</th>        <th class="col_heading level0 col0" >setosa</th>        <th class="col_heading level0 col1" >versicolor</th>        <th class="col_heading level0 col2" >virginica</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778level0_row0" class="row_heading level0 row0" rowspan=3>sepal_length</th>
#                         <th id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778level1_row0" class="row_heading level1 row0" >max</th>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row0_col0" class="data row0 col0" >5.800000</td>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row0_col1" class="data row0 col1" >7.000000</td>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row0_col2" class="data row0 col2" >7.900000</td>
#             </tr>
#             <tr>
#                                 <th id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778level1_row1" class="row_heading level1 row1" >mean</th>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row1_col0" class="data row1 col0" >5.006000</td>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row1_col1" class="data row1 col1" >5.936000</td>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row1_col2" class="data row1 col2" >6.588000</td>
#             </tr>
#             <tr>
#                                 <th id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778level1_row2" class="row_heading level1 row2" >min</th>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row2_col0" class="data row2 col0" >4.300000</td>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row2_col1" class="data row2 col1" >4.900000</td>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row2_col2" class="data row2 col2" >4.900000</td>
#             </tr>
#             <tr>
#                         <th id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778level0_row3" class="row_heading level0 row3" rowspan=3>sepal_width</th>
#                         <th id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778level1_row3" class="row_heading level1 row3" >max</th>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row3_col0" class="data row3 col0" >4.400000</td>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row3_col1" class="data row3 col1" >3.400000</td>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row3_col2" class="data row3 col2" >3.800000</td>
#             </tr>
#             <tr>
#                                 <th id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778level1_row4" class="row_heading level1 row4" >mean</th>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row4_col0" class="data row4 col0" >3.428000</td>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row4_col1" class="data row4 col1" >2.770000</td>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row4_col2" class="data row4 col2" >2.974000</td>
#             </tr>
#             <tr>
#                                 <th id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778level1_row5" class="row_heading level1 row5" >min</th>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row5_col0" class="data row5 col0" >2.300000</td>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row5_col1" class="data row5 col1" >2.000000</td>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row5_col2" class="data row5 col2" >2.200000</td>
#             </tr>
#             <tr>
#                         <th id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778level0_row6" class="row_heading level0 row6" rowspan=3>petal_length</th>
#                         <th id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778level1_row6" class="row_heading level1 row6" >max</th>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row6_col0" class="data row6 col0" >1.900000</td>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row6_col1" class="data row6 col1" >5.100000</td>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row6_col2" class="data row6 col2" >6.900000</td>
#             </tr>
#             <tr>
#                                 <th id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778level1_row7" class="row_heading level1 row7" >mean</th>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row7_col0" class="data row7 col0" >1.462000</td>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row7_col1" class="data row7 col1" >4.260000</td>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row7_col2" class="data row7 col2" >5.552000</td>
#             </tr>
#             <tr>
#                                 <th id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778level1_row8" class="row_heading level1 row8" >min</th>
#                         <td id="T_e48fd232_3ebd_11ed_aa98_e0d55e1c5778row8_col0" class="data row8 col0" >1.000000</td>

# %%
X = iris.T.stack()

# %%
X.index.names = ['feature', 'iris_d']

X
# Out:
# feature       iris_d
# sepal_length  0               5.1
#               1               4.9
#               2               4.7
#               3               4.6
#               4                 5
#                           ...
# species       145       virginica
#               146       virginica
#               147       virginica
#               148       virginica
#               149       virginica
# Length: 750, dtype: object

# %%
# 6.1

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.DataFrame({
    'features':[0.2,-1.1,1.6,5.4],
    'labels':[1,1,0,2]}
)

# %%
df
# Out:
#    features  labels
# 0       0.2       1
# 1      -1.1       1
# 2       1.6       0
# 3       5.4       2

# %%
# 6.2

# %%
df = df.rename(columns={'labels':'label'})

# %%
df
# Out:
#    features  label
# 0       0.2      1
# 1      -1.1      1
# 2       1.6      0
# 3       5.4      2

# %%
# 6.3

# %%
iris = sns.load_dataset('iris')
iris.sort_values(by=['species'], ascending=False)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 149           5.9          3.0           5.1          1.8  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 121           5.6          2.8           4.9          2.0  virginica
# 120           6.9          3.2           5.7          2.3  virginica
# ..            ...          ...           ...          ...        ...
# 31            5.4          3.4           1.5          0.4     setosa
# 30            4.8          3.1           1.6          0.2     setosa
# 29            4.7          3.2           1.6          0.2     setosa
# 28            5.2          3.4           1.4          0.2     setosa
# 0             5.1          3.5           1.4          0.2     setosa
#
# [150 rows x 5 columns]

# %%
# 6.4

# %%
iris.species.value_counts().to_frame('n')
# Out:
#              n
# versicolor  50
# virginica   50
# setosa      50

# %%
# 6.5

# %%
len(iris[
    (iris.petal_length <= 1.4) |
    (iris.petal_length >= 1.6)
])
# Out:
# 137

# %%
iris[(iris.petal_length <= 1.4) | (iris.petal_length >= 1.6)].shape[0]
# Out:
# 137

# %%
# 6.6

# %%
iris['min_petal'] = iris.apply(lambda x: min(x.petal_length, x.petal_width), axis = 1)

iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  min_petal
# 0           5.1          3.5           1.4          0.2  setosa        0.2
# 1           4.9          3.0           1.4          0.2  setosa        0.2
# 2           4.7          3.2           1.3          0.2  setosa        0.2
# 3           4.6          3.1           1.5          0.2  setosa        0.2
# 4           5.0          3.6           1.4          0.2  setosa        0.2

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      min_petal
# 145        2.3
# 146        1.9
# 147        2.0
# 148        2.3
# 149        1.8

# %%
sum(iris.petal_length <= iris.petal_width)
# Out:
# 0

# %%
iris[['petal_length', 'petal_width']].idxmin(axis=1)
# Out:
# 0      petal_width
# 1      petal_width
# 2      petal_width
# 3      petal_width
# 4      petal_width
#           ...
# 145    petal_width
# 146    petal_width
# 147    petal_width
# 148    petal_width
# 149    petal_width
# Length: 150, dtype: object

# %%
iris[['petal_length', 'petal_width']].idxmin(axis=1).value_counts()
# Out:
# petal_width    150
# dtype: int64

# %%
# 6.7

# %%
pd.pivot_table(iris,
              values = ["sepal_width", "petal_width"],
              columns = ["species"],
              aggfunc = {np.mean, np.median})
# Out:
# species             setosa  versicolor  virginica
# petal_width mean     0.246       1.326      2.026
#             median   0.200       1.300      2.000
# sepal_width mean     3.428       2.770      2.974
#             median   3.400       2.800      3.000
